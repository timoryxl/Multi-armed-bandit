# %%
import numpy as np
from numpy.random import multinomial
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
from scipy.stats import bernoulli, beta, binom
from scipy.optimize import minimize
# %matplotlib inline

# %%
def policy(a1, b1, a2, b2, method):
    """
    
    1. policy to determine which machine to select
    2. returns 0 or 1
    3. inputs (a1,a2,b1,b2) should be integers
    4. method should be either exploitation, exploration or proportion
    
    """
    
    if method == 'exploitation':
        return 0 if float(a1)/(a1+b1) > float(a2)/(a2+b2) else 1
    
    elif method == 'exploration':
        return bernoulli.rvs(0.5)
    
    elif method == 'thompson':
        return 0 if beta.rvs(a1,b1) > beta.rvs(a2,b2) else 1

# %%
def rewards(method, N):
    # remove numpy warnings for indexing with non-integers
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")

        machine = np.empty(N)
        reward = np.empty(N)
        theta = np.array([[1,1], # machine 1
                          [1,1]  # machine 2
                         ])

        for t in range(N):

            machine[t] = policy(theta[0][0],
                                theta[0][1],
                                theta[1][0],
                                theta[1][1], method)

            # beta posterior expected value
            reward_theta = float(theta[machine[t]][0])/( theta[machine[t]][0] + theta[machine[t]][1] ) 

            reward[t] = bernoulli.rvs(reward_theta)

            if reward[t] == 1:
                theta[machine[t]][0] += 1 
            else:
                theta[machine[t]][1] += 1
            
        return sum(reward)

# %%
num_games = 200
N = 500
explore = np.zeros(num_games)
exploit = np.zeros(num_games)
thompson = np.zeros(num_games)
for i in range(num_games):
    explore[i] = rewards('exploration', N)
    exploit[i] = rewards('exploitation', N)
    thompson[i] = rewards('thompson', N)

# %%
plt.figure(figsize=(14,8))
plt.title("Comparing Bayesian approaches to Multi-Armed Bandit\n N = {} (number of plays per game)".format(N))
plt.ylabel("Cumulative rewards")
plt.xlabel("Number of games")
plt.plot(np.cumsum(explore))
plt.plot(np.cumsum(exploit))
plt.plot(np.cumsum(thompson))
plt.legend(['Explore','Exploit','Thompson-Sampling'])
plt.show()

# %%
results = {0:{'n':1,'r':0},1:{'n':1,'r':0},2:{'n':1,'r':0}}
machine_reward = np.array([0.5,0.5,0.5])
machine_list = [0,1,2]
R = 0

for t in range(3,300):
    for m in machine_list:
        results[m]['r'] = float(results[m]['r'])/results[m]['n'] + np.sqrt(2*np.log(t)/results[m]['n'])
    machine = np.argmax([v['r'] for k,v in results.items()])
    R += bernoulli.rvs(machine_reward[machine])
    results[machine]['r'] += R
    results[machine]['n'] += 1

    
print results
# Out:
# {0: {'r': 0.66172851122977594, 'n': 28}, 1: {'r': 0.40644205104218001, 'n': 71}, 2: {'r': 147.97364533246662, 'n': 201}}
